# %%
import pandas as pd
a=pd.read_csv("sample.csv")

# %%
a
# Out:
#     Name  Age  Marks
# 0      V   18     20
# 1     JK   19     21
# 2     JM   20     22
# 3     RM   21     23
# 4   SUGA   22     24
# 5    JIN   23     25
# 6  JHOPE   24     26

# %%
a.rename(columns={"Age":"Year","Marks":"Percentage"})
# Out:
#     Name  Year  Percentage
# 0      V    18          20
# 1     JK    19          21
# 2     JM    20          22
# 3     RM    21          23
# 4   SUGA    22          24
# 5    JIN    23          25
# 6  JHOPE    24          26

# %%
a["Marks"].astype("float")
# Out:
# 0    20.0
# 1    21.0
# 2    22.0
# 3    23.0
# 4    24.0
# 5    25.0
# 6    26.0
# Name: Marks, dtype: float64

# %%
a
# Out:
#     Name  Age  Marks
# 0      V   18     20
# 1     JK   19     21
# 2     JM   20     22
# 3     RM   21     23
# 4   SUGA   22     24
# 5    JIN   23     25
# 6  JHOPE   24     26

# %%
a.replace(pd.N3an,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-717965ee0760> in <module>
# ----> 1 a.replace(pd.Nan,10)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'Nan'

# %%
a=pd.read_csv("sample.csv",header=None)

# %%
a
# Out:
#        0    1      2
# 0   Name  Age  Marks
# 1      V   18     20
# 2     JK   19     21
# 3     JM   20     22
# 4     RM   21     23
# 5   SUGA   22     24
# 6    JIN   23     25
# 7  JHOPE   24     26

# %%
# Out:
#        0    1      2
# 0   Name  Age  Marks
# 1      V   18     20
# 2     JK   19     21
# 3     JM   20     22
# 4     RM   21     23
# 5   SUGA   22     24
# 6    JIN   23     25
# 7  JHOPE   24     26
